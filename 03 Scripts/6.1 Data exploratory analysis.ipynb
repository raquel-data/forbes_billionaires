# %% [markdown]
# ### Table of contents
# # 1. Exploratory data analysis
# ### 1.1 Import assets
# ### 1.2 Data consistency and wrangling steps
# ### 1.3 Data cleaning
# ### 1.4 Descriptive analysis
# ### 1.5 Exporting the cleaned data set

# %% [markdown]
# # 1.1 Import assets

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import datasets
path = r'C:\Users\raque\Documents\Achievement 6\Forbes billionaires 1997-2023 analysis'
df_billio = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'all_billionaires_1997_2023.csv'), index_col = False)

# %% [markdown]
# # 1.2 Data consistency and wrangling steps

# %%
df_billio.shape
# Out:
# (31732, 19)

# %%
df_billio.head()
# Out:
#    year  month  rank net_worth     last_name     first_name  \
# 0  1997      7     1     2.0 B  Sophonpanich         Chatri
# 1  1997      7     2     1.8 B     Adulyadej  King Bhumibol
# 2  1998      7     1     3.3 B         Safra         Edmond
# 3  1999      7     1     7.1 B       Schwarz         Dieter
# 4  1999      7     2     2.9 B         Ebner         Martin
#
#                       full_name  birth_date   age gender  \
# 0  Chatri Sophonpanich & family  28/02/1934  73.0   Male
# 1       King Bhumibol Adulyadej  05/12/1927  69.0   Male
# 2                  Edmond Safra  06/08/1932  65.0   Male
# 3                Dieter Schwarz  24/09/1939  59.0   Male
# 4                  Martin Ebner  01/08/1945  53.0   Male
#
#   country_of_citizenship country_of_residence city_of_residence  \
# 0               Thailand             Thailand           Bangkok
# 1               Thailand                  NaN               NaN
# 2                Lebanon              Lebanon               NaN
# 3                Germany              Germany        Neckarsulm
# 4            Switzerland          Switzerland             Wilen
#
#          business_category          business_industries organization_name  \
# 0  Finance and Investments  ['Finance and Investments']               NaN
# 1                      NaN                          NaN               NaN
# 2                      NaN                          NaN               NaN
# 3         Fashion & Retail         ['Fashion & Retail']               NaN
# 4  Finance and Investments  ['Finance and Investments']               NaN
#
#   position_in_organization self_made wealth_status
# 0                      NaN     False           NaN
# 1                      NaN     False           NaN
# 2                      NaN      True           NaN
# 3                      NaN      True           NaN
# 4                      NaN     False           NaN

# %%
df_billio.tail()
# Out:
#        year  month  rank net_worth  last_name first_name  \
# 31727  2023      4  2540     1.0 B         Yu       Rong
# 31728  2023      4  2540     1.0 B  Yuengling    Richard
# 31729  2023      4  2540     1.0 B      Zhang    Gongyun
# 31730  2023      4  2540     1.0 B      Zhang    Guiping
# 31731  2023      4  2540     1.0 B      Zobel      Inigo
#
#                     full_name  birth_date   age gender country_of_citizenship  \
# 31727                 Yu Rong  14/12/1971  51.0   Male                  China
# 31728  Richard Yuengling, Jr.  10/03/1943  80.0   Male          United States
# 31729           Zhang Gongyun  18/12/1962  60.0   Male                  China
# 31730  Zhang Guiping & family  21/08/1951  71.0   Male                  China
# 31731             Inigo Zobel  01/11/1956  66.0   Male            Philippines
#
#       country_of_residence city_of_residence business_category  \
# 31727                China          Shanghai        Healthcare
# 31728        United States        Pottsville   Food & Beverage
# 31729                China             Gaomi     Manufacturing
# 31730                China           Nanjing       Real Estate
# 31731          Philippines            Makati       Diversified
#
#        business_industries organization_name position_in_organization  \
# 31727       ['Healthcare']               NaN                      NaN
# 31728  ['Food & Beverage']               NaN                      NaN
# 31729    ['Manufacturing']               NaN                      NaN
# 31730      ['Real Estate']               NaN                      NaN
# 31731      ['Diversified']               NaN                      NaN
#
#       self_made     wealth_status
# 31727      True         Decreased
# 31728     False     Remained Even
# 31729      True  Returned to List
# 31730      True         Decreased
# 31731     False  Returned to List

# %%
df_billio['net_worth'] = df_billio['net_worth'].str.rstrip(' B')

# %%
df_billio.rename(columns={"net_worth": "net_worth_billions"}, inplace=True)

# %%
df_billio.head(2)
# Out:
#    year  month  rank net_worth_billions     last_name     first_name  \
# 0  1997      7     1                2.0  Sophonpanich         Chatri
# 1  1997      7     2                1.8     Adulyadej  King Bhumibol
#
#                       full_name  birth_date   age gender  \
# 0  Chatri Sophonpanich & family  28/02/1934  73.0   Male
# 1       King Bhumibol Adulyadej  05/12/1927  69.0   Male
#
#   country_of_citizenship country_of_residence city_of_residence  \
# 0               Thailand             Thailand           Bangkok
# 1               Thailand                  NaN               NaN
#
#          business_category          business_industries organization_name  \
# 0  Finance and Investments  ['Finance and Investments']               NaN
# 1                      NaN                          NaN               NaN
#
#   position_in_organization self_made wealth_status
# 0                      NaN     False           NaN
# 1                      NaN     False           NaN

# %%
# Checking missing data 
df_billio.isnull().sum()
# Out:
# year                            0
# month                           0
# rank                            0
# net_worth_billions              0
# last_name                    3689
# first_name                   3747
# full_name                       0
# birth_date                   4404
# age                           675
# gender                       3829
# country_of_citizenship          9
# country_of_residence          702
# city_of_residence             935
# business_category            5843
# business_industries           990
# organization_name           27344
# position_in_organization    27040
# self_made                    3689
# wealth_status                7146
# dtype: int64

# %%
# Check for mixed types
for col in df_billio.columns.tolist():
  weird = (df_billio[[col]].applymap(type) != df_billio[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_billio[weird]) > 0:
    print (col)
# Out:
# last_name
# first_name
# birth_date
# gender
# country_of_citizenship
# country_of_residence
# city_of_residence
# business_category
# business_industries
# organization_name
# position_in_organization
# self_made
# wealth_status

# %%
# Checking data types
df_billio.dtypes
# Out:
# year                          int64
# month                         int64
# rank                          int64
# net_worth_billions           object
# last_name                    object
# first_name                   object
# full_name                    object
# birth_date                   object
# age                         float64
# gender                       object
# country_of_citizenship       object
# country_of_residence         object
# city_of_residence            object
# business_category            object
# business_industries          object
# organization_name            object
# position_in_organization     object
# self_made                    object
# wealth_status                object
# dtype: object

# %%
# Changing data types
df_billio['rank'] = df_billio['rank'].astype('str')
df_billio['net_worth_billions'] = df_billio['net_worth_billions'].astype('float64')
df_billio['last_name'] = df_billio['last_name'].astype('str')
df_billio['first_name'] = df_billio['first_name'].astype('str')
df_billio['birth_date'] = df_billio['birth_date'].astype('str')
df_billio['full_name'] = df_billio['full_name'].astype('str')
df_billio['age'] = df_billio['age'].astype('float')
df_billio['gender'] = df_billio['gender'].astype('str')
df_billio['country_of_citizenship'] = df_billio['country_of_citizenship'].astype('str')
df_billio['country_of_residence'] = df_billio['country_of_residence'].astype('str')
df_billio['city_of_residence'] = df_billio['city_of_residence'].astype('str')
df_billio['business_category'] = df_billio['business_category'].astype('str')
df_billio['business_industries'] = df_billio['business_industries'].astype('str')
df_billio['organization_name'] = df_billio['organization_name'].astype('str')
df_billio['position_in_organization'] = df_billio['position_in_organization'].astype('str')
df_billio['self_made'] = df_billio['self_made'].astype('bool')
df_billio['wealth_status'] = df_billio['wealth_status'].astype('str')

# %% [markdown]
# # 1.3 Data cleaning

# %%
# Removing columns
df_billio = df_billio.drop(columns = ['month', 'birth_date', 'business_category', 'last_name', 'first_name'])

# %%
df_billio.head()
# Out:
#    year rank  net_worth_billions                     full_name   age gender  \
# 0  1997    1                 2.0  Chatri Sophonpanich & family  73.0   Male
# 1  1997    2                 1.8       King Bhumibol Adulyadej  69.0   Male
# 2  1998    1                 3.3                  Edmond Safra  65.0   Male
# 3  1999    1                 7.1                Dieter Schwarz  59.0   Male
# 4  1999    2                 2.9                  Martin Ebner  53.0   Male
#
#   country_of_citizenship country_of_residence city_of_residence  \
# 0               Thailand             Thailand           Bangkok
# 1               Thailand                  nan               nan
# 2                Lebanon              Lebanon               nan
# 3                Germany              Germany        Neckarsulm
# 4            Switzerland          Switzerland             Wilen
#
#            business_industries organization_name position_in_organization  \
# 0  ['Finance and Investments']               nan                      nan
# 1                          nan               nan                      nan
# 2                          nan               nan                      nan
# 3         ['Fashion & Retail']               nan                      nan
# 4  ['Finance and Investments']               nan                      nan
#
#    self_made wealth_status
# 0      False           nan
# 1      False           nan
# 2       True           nan
# 3       True           nan
# 4      False           nan

# %%
# Storing the duplicated values in df_dups
df_dups = df_billio[df_billio.duplicated()]

# %%
# Checking the duplicates 
df_dups
# Out:
#        year rank  net_worth_billions       full_name   age gender  \
# 14219  2016  854                 2.1  Oleg Deripaska  48.0   Male
#
#       country_of_citizenship country_of_residence city_of_residence  \
# 14219                 Russia               Russia            Moscow
#
#        business_industries organization_name position_in_organization  \
# 14219  ['Metals & Mining']               nan                      nan
#
#        self_made wealth_status
# 14219       True     Decreased

# %%
# Dropping the duplicate row
df_billio_no_dups = df_billio.drop_duplicates()

# %% [markdown]
# # 1.4 Descriptive analysis

# %%
df_billio_no_dups.head()
# Out:
#    year rank  net_worth_billions                     full_name   age gender  \
# 0  1997    1                 2.0  Chatri Sophonpanich & family  73.0   Male
# 1  1997    2                 1.8       King Bhumibol Adulyadej  69.0   Male
# 2  1998    1                 3.3                  Edmond Safra  65.0   Male
# 3  1999    1                 7.1                Dieter Schwarz  59.0   Male
# 4  1999    2                 2.9                  Martin Ebner  53.0   Male
#
#   country_of_citizenship country_of_residence city_of_residence  \
# 0               Thailand             Thailand           Bangkok
# 1               Thailand                  nan               nan
# 2                Lebanon              Lebanon               nan
# 3                Germany              Germany        Neckarsulm
# 4            Switzerland          Switzerland             Wilen
#
#            business_industries organization_name position_in_organization  \
# 0  ['Finance and Investments']               nan                      nan
# 1                          nan               nan                      nan
# 2                          nan               nan                      nan
# 3         ['Fashion & Retail']               nan                      nan
# 4  ['Finance and Investments']               nan                      nan
#
#    self_made wealth_status
# 0      False           nan
# 1      False           nan
# 2       True           nan
# 3       True           nan
# 4      False           nan

# %%
df_billio_no_dups.tail()
# Out:
#        year  rank  net_worth_billions               full_name   age gender  \
# 31727  2023  2540                 1.0                 Yu Rong  51.0   Male
# 31728  2023  2540                 1.0  Richard Yuengling, Jr.  80.0   Male
# 31729  2023  2540                 1.0           Zhang Gongyun  60.0   Male
# 31730  2023  2540                 1.0  Zhang Guiping & family  71.0   Male
# 31731  2023  2540                 1.0             Inigo Zobel  66.0   Male
#
#       country_of_citizenship country_of_residence city_of_residence  \
# 31727                  China                China          Shanghai
# 31728          United States        United States        Pottsville
# 31729                  China                China             Gaomi
# 31730                  China                China           Nanjing
# 31731            Philippines          Philippines            Makati
#
#        business_industries organization_name position_in_organization  \
# 31727       ['Healthcare']               nan                      nan
# 31728  ['Food & Beverage']               nan                      nan
# 31729    ['Manufacturing']               nan                      nan
# 31730      ['Real Estate']               nan                      nan
# 31731      ['Diversified']               nan                      nan
#
#        self_made     wealth_status
# 31727       True         Decreased
# 31728      False     Remained Even
# 31729       True  Returned to List
# 31730       True         Decreased
# 31731      False  Returned to List

# %%
df_billio_no_dups.shape
# Out:
# (31731, 14)

# %%
df_billio_no_dups.columns
# Out:
# Index(['year', 'rank', 'net_worth_billions', 'full_name', 'age', 'gender',
#        'country_of_citizenship', 'country_of_residence', 'city_of_residence',
#        'business_industries', 'organization_name', 'position_in_organization',
#        'self_made', 'wealth_status'],
#       dtype='object')

# %%
df_billio_no_dups.info
# Out:
# <bound method DataFrame.info of        year  rank  net_worth_billions                     full_name   age  \
# 0      1997     1                 2.0  Chatri Sophonpanich & family  73.0
# 1      1997     2                 1.8       King Bhumibol Adulyadej  69.0
# 2      1998     1                 3.3                  Edmond Safra  65.0
# 3      1999     1                 7.1                Dieter Schwarz  59.0
# 4      1999     2                 2.9                  Martin Ebner  53.0
# ...     ...   ...                 ...                           ...   ...
# 31727  2023  2540                 1.0                       Yu Rong  51.0
# 31728  2023  2540                 1.0        Richard Yuengling, Jr.  80.0
# 31729  2023  2540                 1.0                 Zhang Gongyun  60.0
# 31730  2023  2540                 1.0        Zhang Guiping & family  71.0
# 31731  2023  2540                 1.0                   Inigo Zobel  66.0
#
#       gender country_of_citizenship country_of_residence city_of_residence  \
# 0       Male               Thailand             Thailand           Bangkok
# 1       Male               Thailand                  nan               nan
# 2       Male                Lebanon              Lebanon               nan
# 3       Male                Germany              Germany        Neckarsulm
# 4       Male            Switzerland          Switzerland             Wilen
# ...      ...                    ...                  ...               ...
# 31727   Male                  China                China          Shanghai
# 31728   Male          United States        United States        Pottsville
# 31729   Male                  China                China             Gaomi
# 31730   Male                  China                China           Nanjing
# 31731   Male            Philippines          Philippines            Makati
#
#                business_industries organization_name position_in_organization  \
# 0      ['Finance and Investments']               nan                      nan
# 1                              nan               nan                      nan
# 2                              nan               nan                      nan
# 3             ['Fashion & Retail']               nan                      nan
# 4      ['Finance and Investments']               nan                      nan
# ...                            ...               ...                      ...
# 31727               ['Healthcare']               nan                      nan
# 31728          ['Food & Beverage']               nan                      nan
# 31729            ['Manufacturing']               nan                      nan
# 31730              ['Real Estate']               nan                      nan
# 31731              ['Diversified']               nan                      nan
#
#        self_made     wealth_status
# 0          False               nan
# 1          False               nan
# 2           True               nan
# 3           True               nan
# 4          False               nan
# ...          ...               ...
# 31727       True         Decreased
# 31728      False     Remained Even
# 31729       True  Returned to List
# 31730       True         Decreased
# 31731      False  Returned to List
#
# [31731 rows x 14 columns]>

# %%
df_billio_no_dups.describe(include = 'object')
# Out:
#          rank      full_name gender country_of_citizenship  \
# count   31731          31731  31731                  31731
# unique    839           4982      3                     89
# top      1818  Robert Miller   Male          United States
# freq      234             27  24867                  10142
#
#        country_of_residence city_of_residence business_industries  \
# count                 31731             31731               31731
# unique                   95              1139                  68
# top           United States          New York   ['Manufacturing']
# freq                  10058              1368                2818
#
#        organization_name position_in_organization wealth_status
# count              31731                    31731         31731
# unique               568                      165             5
# top                  nan                      nan     Increased
# freq               27343                    27039         12367

# %%
df_billio_no_dups.describe()
# Out:
#                year  net_worth_billions           age
# count  31731.000000        31731.000000  31056.000000
# mean    2015.755948            4.022348     62.835555
# std        5.644283            7.105590     14.175046
# min     1997.000000            0.600000      0.000000
# 25%     2012.000000            1.400000     54.000000
# 50%     2017.000000            2.200000     63.000000
# 75%     2021.000000            3.900000     73.000000
# max     2023.000000          219.000000    101.000000

# %% [markdown]
# ## 1.5 Exporting the clean data set

# %%
# Exporting df_billio_no_dups
df_billio_no_dups.to_csv(os.path.join(path, '02 Data','Prepared Data', 'all_billionaires_1997_2023_clean.csv'), index=False)
